# %%
from viewx.datasets import load_dataset
from viewx import HTML
import matplotlib.pyplot as plt

# %%
df
# Out:
#       Year  Rank Country name  Ladder score  upperwhisker  lowerwhisker  \
# 0     2024     1      Finland         7.736         7.810         7.662
# 1     2023   143  Afghanistan         1.721         1.775         1.667
# 2     2022   137  Afghanistan         1.859         1.923         1.795
# 3     2021   146  Afghanistan         2.404         2.469         2.339
# 4     2020   150  Afghanistan         2.523         2.596         2.449
# ...    ...   ...          ...           ...           ...           ...
# 1964  2016   138     Zimbabwe         3.875           NaN           NaN
# 1965  2015   131     Zimbabwe         4.193           NaN           NaN
# 1966  2014   115     Zimbabwe         4.610           NaN           NaN
# 1967  2012   103     Zimbabwe         4.827           NaN           NaN
# 1968  2011   142     Zimbabwe         3.978           NaN           NaN
#
#       Explained by: Log GDP per capita  Explained by: Social support  \
# 0                                1.749                         1.783
# 1                                0.628                         0.000
# 2                                0.645                         0.000
# 3                                0.758                         0.000
# 4                                0.370                         0.000
# ...                                ...                           ...
# 1964                               NaN                           NaN
# 1965                               NaN                           NaN
# 1966                               NaN                           NaN
# 1967                               NaN                           NaN
# 1968                               NaN                           NaN
#
#       Explained by: Healthy life expectancy  \
# 0                                     0.824
# 1                                     0.242
# 2                                     0.087
# 3                                     0.289
# 4                                     0.126
# ...                                     ...
# 1964                                    NaN
# 1965                                    NaN
# 1966                                    NaN
# 1967                                    NaN
# 1968                                    NaN
#
#       Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                          0.986                     0.110
# 1                                          0.000                     0.091
# 2                                          0.000                     0.093
# 3                                          0.000                     0.089
# 4                                          0.000                     0.122
# ...                                          ...                       ...
# 1964                                         NaN                       NaN
# 1965                                         NaN                       NaN
# 1966                                         NaN                       NaN
# 1967                                         NaN                       NaN
# 1968                                         NaN                       NaN
#
#       Explained by: Perceptions of corruption  Dystopia + residual
# 0                                       0.502                1.782
# 1                                       0.088                0.672
# 2                                       0.059                0.976
# 3                                       0.005                1.263
# 4                                       0.010                1.895
# ...                                       ...                  ...
# 1964                                      NaN                  NaN
# 1965                                      NaN                  NaN
# 1966                                      NaN                  NaN
# 1967                                      NaN                  NaN
# 1968                                      NaN                  NaN
#
# [1969 rows x 13 columns]

# %%
df = load_dataset("WHR25_Data_Figure_2.1.xlsx")
df.groupby(by=["Country name", "Year"]).mean(True)
# Out:
#                     Rank  Ladder score  upperwhisker  lowerwhisker  \
# Country name Year
# Afghanistan  2011  131.0         4.258           NaN           NaN
#              2012  143.0         4.040           NaN           NaN
#              2014  153.0         3.575           NaN           NaN
#              2015  154.0         3.360           NaN           NaN
#              2016  141.0         3.794           NaN           NaN
# ...                  ...           ...           ...           ...
# Zimbabwe     2020  149.0         3.145         3.259         3.030
#              2021  144.0         2.995         3.110         2.880
#              2022  134.0         3.204         3.323         3.084
#              2023  138.0         3.341         3.457         3.226
#              2024  143.0         3.396         3.509         3.283
#
#                    Explained by: Log GDP per capita  \
# Country name Year
# Afghanistan  2011                               NaN
#              2012                               NaN
#              2014                               NaN
#              2015                               NaN
#              2016                               NaN
# ...                                             ...
# Zimbabwe     2020                             0.457
#              2021                             0.947
#              2022                             0.758
#              2023                             0.748
#              2024                             0.827
#
#                    Explained by: Social support  \
# Country name Year
# Afghanistan  2011                           NaN
#              2012                           NaN
#              2014                           NaN
#              2015                           NaN
#              2016                           NaN
# ...                                         ...
# Zimbabwe     2020                         0.649
#              2021                         0.690
#              2022                         0.881
#              2023                         0.850
#              2024                         0.961
#
#                    Explained by: Healthy life expectancy  \
# Country name Year
# Afghanistan  2011                                    NaN
#              2012                                    NaN
#              2014                                    NaN
#              2015                                    NaN
#              2016                                    NaN
# ...                                                  ...
# Zimbabwe     2020                                  0.243
#              2021                                  0.270
#              2022                                  0.069
#              2023                                  0.232
#              2024                                  0.178
#
#                    Explained by: Freedom to make life choices  \
# Country name Year
# Afghanistan  2011                                         NaN
#              2012                                         NaN
#              2014                                         NaN
#              2015                                         NaN
#              2016                                         NaN
# ...                                                       ...
# Zimbabwe     2020                                       0.359
#              2021                                       0.329
#              2022                                       0.363
#              2023                                       0.487
#              2024                                       0.598
#
#                    Explained by: Generosity  \
# Country name Year
# Afghanistan  2011                       NaN
#              2012                       NaN
#              2014                       NaN
#              2015                       NaN
#              2016                       NaN
# ...                                     ...
# Zimbabwe     2020                     0.157
#              2021                     0.106
#              2022                     0.112
#              2023                     0.096
#              2024                     0.065
#
#                    Explained by: Perceptions of corruption  \
# Country name Year
# Afghanistan  2011                                      NaN
#              2012                                      NaN
#              2014                                      NaN
#              2015                                      NaN
#              2016                                      NaN
# ...                                                    ...
# Zimbabwe     2020                                    0.075
#              2021                                    0.105
#              2022                                    0.117
#              2023                                    0.131
#              2024                                    0.131
#
#                    Dystopia + residual
# Country name Year
# Afghanistan  2011                  NaN
#              2012                  NaN
#              2014                  NaN
#              2015                  NaN
#              2016                  NaN
# ...                                ...
# Zimbabwe     2020                1.205
#              2021                0.548
#              2022                0.905
#              2023                0.797
#              2024                0.636
#
# [1969 rows x 11 columns]

# %% [markdown]
# # Pagina Principal HTML

# %%
dataset_page = HTML(
    data=df,
    title="World Happiness Dataset",
    template_color=6,
    num_divs=3,
    num_cols=9,
    num_rows=3
)
# Out:
# ¡Bienvenido a ViewX!
# Encendiendo Motores...

# %%
dataset_page.add_text(
    f"""
    <style>
        title {{
            transition: 0.3s ease;
        }}
        .title:hover {{
            transform: scale(1.1);
            transition: 0.2s;
        }}
        ::-webkit-scrollbar {{
            display: none;
        }}

    </style>
    <div style="align-items: center;">
        <h1 class = "title" style = "
                    text-align: center; 
                    font-size: 90px;
                    ">
                    World Happiness Dataset
        </h1>
    </div>
    """,
    slot_grid=("div1", 1, 1, 1, 7)
)
# Out:
# Cargando Texto...

# %%
dataset_page.add_table(
    slot_grid=("div2", 2, 1, 2, 9)
)
# Out:
# Cargando Tabla...

# %%
dataset_page.add_text(
    f"""
        <style>
    .button_dataset:hover {{
        opacity: 0.9;
        transform: scale(1.5);
    }}

    .img-dataset:hover {{
        transform: scale(1.15) rotate(3deg);
        filter: brightness(1.2) drop-shadow(0px 4px 10px rgba(0,0,0,0.4));
    }}

    h1,
    h2 {{
        transition: 0.3s ease;
    }}

    h1:hover,
    h1:hover {{
        transform: scale(1.15);
        transition: 0.3s;
    }}

    </style>
    <div style="
        display: grid;
        grid-template-columns: repeat(auto-fit, minmax(150px, 1fr));
        gap: 15px;
        align-items: center;
        justify-items: center;
        margin-top: 10%;">

        <a href="main_page.html">
            <button class = "button_dataset" style="
                background-color: {dataset_page.templates[6][2]};
                color: white;
                padding: 15px 30px;
                border: none;
                border-radius: 5px;
                font-size: 16px;
                cursor: pointer;
                transition: 0.3s;
                margin-top: 15px;
                align-items: right;">
                Home
            </button>
        </a>
        <a href="world_page.html">
            <button class = "button_dataset" style="
                background-color: {dataset_page.templates[6][2]};
                color: white;
                padding: 15px 30px;
                border: none;
                border-radius: 5px;
                font-size: 16px;
                cursor: pointer;
                transition: 0.3s;
                margin-top: 15px;
                align-items: right;">
                World
            </button>
        </a>
        <a href="continent_page.html">
            <button class = "button_dataset" style="
                background-color: {dataset_page.templates[6][2]};
                color: white;
                padding: 15px 30px;
                border: none;
                border-radius: 5px;
                font-size: 16px;
                cursor: pointer;
                transition: 0.3s;
                margin-top: 15px;
                align-items: right;">
                Continents
            </button>
        </a>
        <a href="countries_page.html">
            <button class = "button_dataset" style="
                background-color: {dataset_page.templates[6][2]};
                color: white;
                padding: 15px 30px;
                border: none;
                border-radius: 5px;
                font-size: 16px;
                cursor: pointer;
                transition: 0.3s;
                margin-top: 15px;
                align-items: right;">
                Countries
            </button>
        </a>
    </div>
    """,
    slot_grid=("div3", 1, 8, 1, 2)
)
# Out:
# Cargando Texto...

# %%
dataset_page.show("dataset_page.html")
# Out:
# Mostrando HTML...
# Exportando HTML...
